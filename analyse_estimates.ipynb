# %%
from util import get_summary, plot_estimates, read_json_file

# %%
file_dir = "forcast_output.json"

# %% [markdown]
# You can also visualize the mempool based fee estimates with threshold of estimatesmartfee

# %%
data = read_json_file(file_dir, BitcoindThreshold=False)

# %%
forecaster = "Mempool Forecast"

# %%
get_summary(data, forecaster)
# Out:
# Total of 13718 estimates were made from 2024-06-07 12:18:25 to 2024-06-10 07:48:05 from Block 846886 to Block 847321
# ---------------------------------------------------------
# Low priority estimates
# 0 estimates overpaid 0.00% of the total estimates
# 1866 estimates underpaid 47.71% of the total estimates
# 2045 estimates are within the range 52.29% of the total estimates
# ---------------------------------------------------------
# High priority estimate
# 15 estimates overpaid 0.38% of the total estimates
# 1193 estimates underpaid 30.50% of the total estimates
# 2703 estimates are within the range 69.11% of the total estimates
# ---------------------------------------------------------
# Bitcoind conservative estimate
# 3760 estimates overpaid 96.14% of the total estimates
# 66 estimates underpaid 1.69% of the total estimates
# 85 estimates are within the range 2.17% of the total estimates
# ---------------------------------------------------------
# ...

# %% [markdown]
# Plot the graph of fee estimates from Block 832331 to Block 832400
#
# `plot_estimates` function can only plot the range of 200 blocks at max.

# %%
plot_estimates(846887, 847087, data, forecaster=Mempool, logscale_yaxis=True)
