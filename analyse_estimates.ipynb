# %%
from util import get_summary, plot_estimates, read_json_file

# %%
file_dir = "estimates_with_quartiles.json"

# %% [markdown]
# You can also visualize the mempool based fee estimates with threshold of estimatesmartfee

# %%
file_dir = "estimates_with_quartiles_with_threshold.json"

# %%
data = read_json_file(file_dir)

# %%
get_summary(data)
# Out:
# Total of 19154 estimates were made from 2024-02-28 01:57:56 to 2024-03-12 13:23:05 from Block 832330 to Block 834362
# ---------------------------------------------------------
# CBlockPolicyEstimator estimatesmartfee economic mode with confirmation target 1
# 5643 estimates overpaid 29.46% of the total estimates
# 2114 estimates underpaid 11.04% of the total estimates
# 11397 estimates are within the range 59.50% of the total estimates
# ---------------------------------------------------------
# Mempool estimate for next block
# 6 estimates overpaid 0.03% of the total estimates
# 5070 estimates underpaid 26.47% of the total estimates
# 14078 estimates are within the range 73.50% of the total estimates

# %% [markdown]
# Plot the graph of fee estimates from Block 832331 to Block 832400
#
# `plot_estimates` function can only plot the range of 200 blocks at max.

# %%
plot_estimates(832331, 832500, data, logscale_yaxis=True)

# %%
plot_estimates(832331, 832500, data, logscale_yaxis=True)
